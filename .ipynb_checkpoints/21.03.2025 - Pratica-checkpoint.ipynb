# %%
import pandas as pd

# Carica il dataset

pub = pd.read_csv("Mappa-dei-pub-circoli-locali-in-Italia.csv", encoding="latin1", sep=";")
display(pub)
# Out:
#             Comune                       Provincia   Regione             Nome  \
# 0            ALTRO                           ALTRO     ALTRO              NaN
# 1            ALTRO                           ALTRO     ALTRO      Lenny's Pub
# 2            ALTRO                           ALTRO     ALTRO  Murrayfield Pub
# 3            ALTRO                           ALTRO     ALTRO           Snop?e
# 4     ALA DI STURA  CITTA' METROPOLITANA DI TORINO  Piemonte              NaN
# ...            ...                             ...       ...              ...
# 2630      BARLETTA           BARLETTA-ANDRIA-TRANI    Puglia      Santa Croce
# 2631     BISCEGLIE           BARLETTA-ANDRIA-TRANI    Puglia      Auld Dublin
# 2632     BISCEGLIE           BARLETTA-ANDRIA-TRANI    Puglia            Ferus
# 2633         TRANI           BARLETTA-ANDRIA-TRANI    Puglia          Re Artù
# 2634         TRANI           BARLETTA-ANDRIA-TRANI    Puglia     Well's Fargo
#
# ...

# %%
# Import pandas library for data manipulation and analysis
import pandas as pd

# Load the pub dataset from CSV file
# Using latin1 encoding to handle special characters
# Semicolon (;) is used as the column separator
pub = pd.read_csv("Mappa-dei-pub-circoli-locali-in-Italia.csv", encoding="latin1", sep=";")

# Display the entire dataframe
display(pub)
# Out:
#             Comune                       Provincia   Regione             Nome  \
# 0            ALTRO                           ALTRO     ALTRO              NaN
# 1            ALTRO                           ALTRO     ALTRO      Lenny's Pub
# 2            ALTRO                           ALTRO     ALTRO  Murrayfield Pub
# 3            ALTRO                           ALTRO     ALTRO           Snop?e
# 4     ALA DI STURA  CITTA' METROPOLITANA DI TORINO  Piemonte              NaN
# ...            ...                             ...       ...              ...
# 2630      BARLETTA           BARLETTA-ANDRIA-TRANI    Puglia      Santa Croce
# 2631     BISCEGLIE           BARLETTA-ANDRIA-TRANI    Puglia      Auld Dublin
# 2632     BISCEGLIE           BARLETTA-ANDRIA-TRANI    Puglia            Ferus
# 2633         TRANI           BARLETTA-ANDRIA-TRANI    Puglia          Re Artù
# 2634         TRANI           BARLETTA-ANDRIA-TRANI    Puglia     Well's Fargo
#
# ...

# %%
sorted( pub.loc[:, "Anno inserimento"].unique() )
# Out:
# [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016]

# %%
# Sort unique values in the "Anno inserimento" (Insertion Year) column of the pub DataFrame
# Returns a sorted list of all distinct years when items were inserted
sorted( pub.loc[:, "Anno inserimento"].unique() )
# Out:
# [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016]

# %%
filtro_lon = (9 < pub["Longitudine"]) & (pub["Longitudine"] <= 10)
filtro_lan = (45 < pub["Latitudine"]) & (pub["Latitudine"] <= 46)
filtro = filtro_lon & filtro_lan 
pub.loc[filtro].shape
# Out:
# (306, 9)

# %%
provincia = "Vicenza"
filtro_prov = pub["Provincia"] == provincia.upper()
pub.loc[filtro_prov].shape
# Out:
# (73, 9)

# %%
for nome in pub["Nome"]:
    if type(nome) != float:
        nome_min = nome.lower()
        if "enoteca" in nome_min:
            print(nome)
# Out:
# Enoteca con Cucina""Tirolin""
# Concordia Enoteca
# Enoteca Umberto
# Enoteca ""Al Brindisi""
# Enoteca ""da Massimo""
# Enoteca Il Violino Rosso

# %%
for nome in pub["Nome"]:
    if type(nome) != float:
        nome_min = nome.lower()
        if ("vineria" in nome_min) and ("bar" not in nome_min):
            print(nome)
# Out:
# Vineria del Pozzo

# %%
nome = pub.sample()["Nome"]
print(str(nome))
# Out:
# 1373    Missy
# Name: Nome, dtype: object

# %%
lista_nomi = []

# %%
str(nome).split()
# Out:
# ['1373', 'Missy', 'Name:', 'Nome,', 'dtype:', 'object']

# %%
nome = "Lenny's Pub"
tokens = nome.split()
lista_nomi.extend( tokens )

# %%
lista_nomi
# Out:
# ["Lenny's", 'Pub']

# %%
lista_nomi = []

for nome in pub["Nome"]:
    if type(nome) != float:
        nome_min = nome.lower()
        tokens = nome_min.split()
        lista_nomi.extend( tokens )

# %%
lista_nomi = pd.Series(lista_nomi)  #casting
lista_nomi.value_counts()  [:20]
# Out:
# pub         415
# bar         161
# la          141
# birreria    102
# il           81
# the          68
# del          43
# irish        41
# cafè         39
# osteria      34
# al           33
# club         28
# e            26
# beer         26
# le           22
# &            22
# -            22
# da           22
# old          21
# di           21
# Name: count, dtype: int64

# %%
lista_nomi = pd.Series(lista_nomi)  #casting
token_conta = lista_nomi.value_counts() 
altre_categorie = token_conta.index[1:30]

# %%
lista_nomi = pd.Series(lista_nomi)  #casting
token_conta = lista_nomi.value_counts() 
token_conta.index[-30:]
# Out:
# Index(['sketch', 'principal', 'bierschupfe', '12erl', 'freyhaus', 'alm',
#        'moaregg', 'sporthütte', 'pfiff', 'skialm', 'takatuka', 'corona',
#        'luislkeller', 'apres-ski', 'fux', 'zentral', 'nals', 'weber',
#        'gasthof', 'prosecco', 'ratschings', 'sportzone', 'platzl',
#        'graswegerkeller', 'formerkeller', '181', 'tschurtsch', 'buschenschank',
#        's?itipftl', 'fargo'],
#       dtype='object')

# %%
#lista_nomi = pd.Series(lista_nomi)  #casting
#token_conta = lista_nomi.value_counts() 
altre_categorie = token_conta.index[1:30]

# %%
lista_pub_e_basta = []
for nome in pub["Nome"]:
    if type(nome) != float:
        nome_min = nome.lower()
        tokens = nome_min.split()
        if "pub" in tokens and len(set(tokens).intersection(set(altre_categorie)))==0:
            lista_pub_e_basta.append(nome)
    
len(lista_pub_e_basta)
# Out:
# 299

# %%
tokens = ["pub", "birreria", "pizzeria", "da", "zio", "giovanni"]
categorie = ["birreria", "discoteca", "pizzeria", "bar"]
tokens = set(tokens)
categorie = set(categorie)

# %%
tokens
# Out:
# {'birreria', 'da', 'giovanni', 'pizzeria', 'pub', 'zio'}

# %%
categorie
# Out:
# {'bar', 'birreria', 'discoteca', 'pizzeria'}

# %%
lista_pub_e_basta = []
for nome in pub["Nome"]:
    if type(nome) != float:
        nome_min = nome.lower()
        tokens = nome_min.split()
        tokens = set(tokens)
        altre_categorie = set(altre_categorie)
        intersezione = tokens.intersection(altre_categorie)
        if "pub" in tokens and len(intersezione)==0:
            lista_pub_e_basta.append(nome)
            print(nome)
len(lista_pub_e_basta)
# Out:
# Lenny's Pub
# Murrayfield Pub
# Pub Sheerwood
# Walter's Pub
# Sailor's Pub
# Mister Gipson Pub
# Pub Marconi
# Saint George Music Pub
# Beppe's Pub
# John Lennon's Pub
# Manhattan Pub
# New Castle Pub
# Piper Pub
# Pub James Joyce
# Pub Sherlock Holmes
# Shakespeare Pub
# Britannia Pub
# Blue Ribbon Pub
# Rendez Vous Pub
# Bujo Pub
# Befed Brew Pub
# Calypso pub
# John's Pub
# L'Irish Pub
# Bulldog Pub
# Big Ben Pub
# Britannia Pub
# Caledonian Pub
# Hemingway'S Pub
# Hofbrauhaus Pub
# Mackenny Brewery Pub
# MacKenny Pub
# Okey Pub
# Pub D'oh
# Pub Rossodisera
# Tartan Pub
# Bulldog Pub
# Crazy Pub
# Queen Pub
# Lord Nelson Pub
# Murphy's Pub
# Pub 99
# Ralph's Pub
# Duedipicche Live Pub
# Music Pub Buena Vista
# Pub Camino
# pub all'aperto ""il Castello""
# Texas Rangers Pub
# Zymè Pub
# Las Vegas Pub
# Las Vegas Pub
# Place's Pub
# Higlander Pub
# Madigan's Pub
# Five Pub
# Soho Pub
# Wallaby Pub
# camillo's Pub
# Diana Pub
# Gecho's pub
# Guru Pub
# Harp Pub
# Jutland Pub
# ...

# %%
enoteche = []
for nome in pub["Nome"]:
    if type(nome) != float:
        nome_min = nome.lower()
        if "enoteca" in nome_min:
            enoteche.append(nome)
len(enoteche)
enoteche
# Out:
# ['Enoteca con Cucina""Tirolin""',
#  'Concordia Enoteca',
#  'Enoteca Umberto',
#  'Enoteca ""Al Brindisi""',
#  'Enoteca ""da Massimo""',
#  'Enoteca Il Violino Rosso']

# %%
filtro = pub["Nome"].fillna("").str.lower().str.contains("enoteca")
pub.loc[filtro]
# Out:
#                    Comune                       Provincia         Regione  \
# 64                 TORINO  CITTA' METROPOLITANA DI TORINO        Piemonte
# 496                MILANO  CITTA' METROPOLITANA DI MILANO       Lombardia
# 1003                 MALO                         VICENZA          Veneto
# 1491              FERRARA                         FERRARA  Emilia-Romagna
# 1492              FERRARA                         FERRARA  Emilia-Romagna
# 1723  CASCIANA TERME LARI                            PISA         Toscana
#
#                                Nome  Anno inserimento Data e ora inserimento  \
# 64    Enoteca con Cucina""Tirolin""              2012   2012-01-24T14:30:04Z
# 496               Concordia Enoteca              2014   2014-04-01T11:15:38Z
# 1003                Enoteca Umberto              2013   2013-04-15T08:41:22Z
# 1491        Enoteca ""Al Brindisi""              2015   2015-03-31T17:33:38Z
# ...

# %%
# Create a boolean mask by checking if 'Nome' column contains 'enoteca'
# 1. Fill NaN values with empty string
# 2. Convert to lowercase
# 3. Check if string contains 'enoteca'
pub["Nome"].fillna("").str.lower().str.contains("enoteca")

# Filter DataFrame using the boolean mask
pub.loc[filtro]
# Out:
#                    Comune                       Provincia         Regione  \
# 64                 TORINO  CITTA' METROPOLITANA DI TORINO        Piemonte
# 496                MILANO  CITTA' METROPOLITANA DI MILANO       Lombardia
# 1003                 MALO                         VICENZA          Veneto
# 1491              FERRARA                         FERRARA  Emilia-Romagna
# 1492              FERRARA                         FERRARA  Emilia-Romagna
# 1723  CASCIANA TERME LARI                            PISA         Toscana
#
#                                Nome  Anno inserimento Data e ora inserimento  \
# 64    Enoteca con Cucina""Tirolin""              2012   2012-01-24T14:30:04Z
# 496               Concordia Enoteca              2014   2014-04-01T11:15:38Z
# 1003                Enoteca Umberto              2013   2013-04-15T08:41:22Z
# 1491        Enoteca ""Al Brindisi""              2015   2015-03-31T17:33:38Z
# ...

# %%
print(pub.shape)
pub = pub.dropna(subset="Nome")
print(pub.shape)
filtro = pub["Nome"].str.lower().str.contains("enoteca")
pub.loc[filtro]
# Out:
# (2635, 9)
# (2337, 9)
#                    Comune                       Provincia         Regione  \
# 64                 TORINO  CITTA' METROPOLITANA DI TORINO        Piemonte
# 496                MILANO  CITTA' METROPOLITANA DI MILANO       Lombardia
# 1003                 MALO                         VICENZA          Veneto
# 1491              FERRARA                         FERRARA  Emilia-Romagna
# 1492              FERRARA                         FERRARA  Emilia-Romagna
# 1723  CASCIANA TERME LARI                            PISA         Toscana
#
#                                Nome  Anno inserimento Data e ora inserimento  \
# 64    Enoteca con Cucina""Tirolin""              2012   2012-01-24T14:30:04Z
# 496               Concordia Enoteca              2014   2014-04-01T11:15:38Z
# 1003                Enoteca Umberto              2013   2013-04-15T08:41:22Z
# 1491        Enoteca ""Al Brindisi""              2015   2015-03-31T17:33:38Z
# ...

# %%
pub["Comune"].nunique()
# Out:
# 861

# %%
ins = pd.read_csv("insurance.csv")

# %%
ins.groupby("region")["charges"].mean()
# Out:
# region
# northeast    13406.384516
# northwest    12417.575374
# southeast    14735.411438
# southwest    12346.937377
# Name: charges, dtype: float64

# %%
ins.groupby("smoker")["charges"].mean()
# Out:
# smoker
# no      8434.268298
# yes    32050.231832
# Name: charges, dtype: float64

# %%
ins.groupby("sex")["charges"].mean()
# Out:
# sex
# female    12569.578844
# male      13956.751178
# Name: charges, dtype: float64

# %%
ins.groupby(["region", "smoker", "sex"])["charges"].mean()
# Out:
# region     smoker  sex
# northeast  no      female     9640.426984
#                    male       8664.042222
#            yes     female    28032.046398
#                    male      30926.252583
# northwest  no      female     8786.998679
#                    male       8320.689321
#            yes     female    29670.824946
#                    male      30713.181419
# southeast  no      female     8440.205552
#                    male       7609.003587
#            yes     female    33034.820716
#                    male      36029.839367
# southwest  no      female     8234.091260
#                    male       7778.905534
#            yes     female    31687.988430
#                    male      32598.862854
# Name: charges, dtype: float64

# %%
analisi = ins.groupby(["region", "smoker", "sex"])["charges"].mean().to_frame()

# %%
analisi.xs("northeast")
# Out:
#                     charges
# smoker sex
# no     female   9640.426984
#        male     8664.042222
# yes    female  28032.046398
#        male    30926.252583

# %%
analisi.loc[("northeast", "yes", "female")]
# Out:
# charges    28032.046398
# Name: (northeast, yes, female), dtype: float64

# %%
nome_dei_quartili = ["q1", "q2", "q3", "q4"]
ins['qbmi'] = pd.qcut(ins["bmi"], 4, labels=["q1", "q2", "q3", "q4"])

# %%
ins
# Out:
#       age     sex     bmi  children smoker     region      charges qbmi
# 0      19  female  27.900         0    yes  southwest  16884.92400   q2
# 1      18    male  33.770         1     no  southeast   1725.55230   q3
# 2      28    male  33.000         3     no  southeast   4449.46200   q3
# 3      33    male  22.705         0     no  northwest  21984.47061   q1
# 4      32    male  28.880         0     no  northwest   3866.85520   q2
# ...   ...     ...     ...       ...    ...        ...          ...  ...
# 1333   50    male  30.970         3     no  northwest  10600.54830   q3
# 1334   18  female  31.920         0     no  northeast   2205.98080   q3
# 1335   18  female  36.850         0     no  southeast   1629.83350   q4
# 1336   21  female  25.800         0     no  southwest   2007.94500   q1
# 1337   61  female  29.070         0    yes  northwest  29141.36030   q2
#
# [1338 rows x 8 columns]

# %%
ins.groupby("qbmi")["charges"].agg(['min', 'mean', 'max'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18300\2828716169.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ins.groupby("qbmi")["charges"].agg(['min', 'mean', 'max'])
#             min          mean          max
# qbmi
# q1    1121.8739  10360.662825  38245.59327
# q2    1131.5066  11407.831468  62592.87309
# q3    1135.9407  14358.173081  60021.39897
# q4    1141.4451  16987.936691  63770.42801

# %%
iris = pd.read_csv("iris.csv")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris["petal_length"].mean()
# Out:
# 3.758666666666666

# %%
iris.groupby("species")["petal_length"].mean()
# Out:
# species
# Iris-setosa        1.464
# Iris-versicolor    4.260
# Iris-virginica     5.552
# Name: petal_length, dtype: float64

# %%
iris.groupby('species')['sepal_width'].agg(['mean', 'min', 'max'])
# Out:
#                   mean  min  max
# species
# Iris-setosa      3.418  2.3  4.4
# Iris-versicolor  2.770  2.0  3.4
# Iris-virginica   2.974  2.2  3.8

# %%
wine = pd.read_csv("wine.csv")

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
print(wine['alcohol'].mean())
# Out:
# 10.491800831149453

# %%
wine.groupby("quality")["alcohol"].mean()
# Out:
# quality
# 3    10.215000
# 4    10.180093
# 5     9.837783
# 6    10.587553
# 7    11.386006
# 8    11.678756
# 9    12.180000
# Name: alcohol, dtype: float64

# %%
wine.groupby('type')['alcohol'].mean()
# Out:
# type
# red      10.422983
# white    10.514267
# Name: alcohol, dtype: float64

# %%
wine.groupby("type")["pH"].mean()
# Out:
# type
# red      3.311113
# white    3.188267
# Name: pH, dtype: float64

# %%
wine.groupby("quality")["pH"].mean()
# Out:
# quality
# 3    3.257667
# 4    3.231620
# 5    3.212189
# 6    3.217726
# 7    3.228072
# 8    3.223212
# 9    3.308000
# Name: pH, dtype: float64

# %%
wine.groupby(["quality",'type'])['type'].size()
# Out:
# quality  type
# 3        red        10
#          white      20
# 4        red        53
#          white     163
# 5        red       681
#          white    1457
# 6        red       638
#          white    2198
# 7        red       199
#          white     880
# 8        red        18
#          white     175
# 9        white       5
# Name: type, dtype: int64

# %%
boston = pd.read_csv('boston.csv')
boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
boston['chas'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
boston.groupby('chas')['medv'].mean()
# Out:
# chas
# 0    22.093843
# 1    28.440000
# Name: medv, dtype: float64

# %%
boston.groupby("crim")["medv"].mean().iloc[-20:]
# Out:
# crim
# 18.8110    17.9
# 19.6091    15.0
# 20.0849     8.8
# 20.7162    11.9
# 22.0511    10.5
# 22.5971     7.4
# 23.6482    13.1
# 24.3938    10.5
# 24.8017     8.3
# 25.0461     5.6
# 25.9406    10.4
# 28.6558    16.3
# 37.6619    10.9
# 38.3518     5.0
# 41.5292     8.5
# 45.7461     7.0
# 51.1358    15.0
# 67.9208     5.0
# 73.5341     8.8
# 88.9762    10.4
# Name: medv, dtype: float64

# %%
boston.groupby("ptratio")["rm"].mean()
# Out:
# ptratio
# 12.6    7.222667
# 13.0    7.406167
# 13.6    7.923000
# 14.4    7.875000
# 14.7    6.246235
# 14.8    6.752333
# 14.9    7.311250
# 15.1    6.816000
# 15.2    6.421923
# 15.3    6.705333
# 15.5    7.241000
# 15.6    6.702000
# 15.9    6.997000
# 16.0    6.230600
# 16.1    6.428800
# 16.4    6.139667
# 16.6    6.344188
# 16.8    6.146750
# 16.9    6.016400
# 17.0    6.868250
# 17.3    6.383000
# 17.4    7.212333
# 17.6    6.822429
# 17.8    6.496130
# 17.9    6.134818
# 18.0    7.218600
# 18.2    6.283000
# 18.3    6.520500
# 18.4    6.285938
# 18.5    6.288750
# 18.6    6.111588
# 18.7    6.406556
# 18.8    5.956000
# 18.9    5.785667
# 19.0    6.453750
# 19.1    6.234882
# 19.2    6.053632
# 19.6    6.224000
# 19.7    6.303250
# 20.1    5.585400
# 20.2    6.024021
# 20.9    6.266273
# 21.0    6.039778
# 21.1    5.888000
# 21.2    6.028533
# 22.0    5.799500
# Name: rm, dtype: float64

# %%
boston.groupby("ptratio")["medv"].mean()
# Out:
# ptratio
# 12.6    32.733333
# 13.0    38.025000
# 13.6    50.000000
# 14.4    50.000000
# 14.7    25.717647
# 14.8    25.433333
# 14.9    40.475000
# 15.1    31.600000
# 15.2    26.276923
# 15.3    26.066667
# 15.5    32.700000
# 15.6    30.100000
# 15.9    30.250000
# 16.0    24.320000
# 16.1    24.880000
# 16.4    23.216667
# 16.6    23.856250
# 16.8    22.150000
# 16.9    19.640000
# 17.0    30.600000
# 17.3    24.700000
# 17.4    33.544444
# 17.6    30.700000
# 17.8    26.956522
# 17.9    22.363636
# 18.0    33.100000
# 18.2    22.150000
# 18.3    27.100000
# 18.4    23.131250
# 18.5    23.800000
# 18.6    24.335294
# 18.7    25.122222
# 18.8    17.350000
# 18.9    20.100000
# 19.0    24.900000
# 19.1    22.894118
# 19.2    22.805263
# 19.6    22.575000
# 19.7    21.787500
# 20.1    12.800000
# 20.2    16.611429
# 20.9    21.118182
# 21.0    17.351852
# 21.1    18.900000
# 21.2    17.093333
# 22.0    19.400000
# Name: medv, dtype: float64

# %%
boston.groupby("rad")["age"].mean()
# Out:
# rad
# 1     45.025000
# 2     64.770833
# 3     49.310526
# 4     60.841818
# 5     69.223478
# 6     60.142308
# 7     40.141176
# 8     67.350000
# 24    89.805303
# Name: age, dtype: float64

# %%
boston.groupby("rad")["rm"].mean()
# Out:
# rad
# 1     6.555850
# 2     6.649958
# 3     6.473026
# 4     6.133118
# 5     6.393157
# 6     6.104731
# 7     6.647765
# 8     6.950792
# 24    6.022152
# Name: rm, dtype: float64

# %%
boston.groupby("rad")["tax"].mean()
# Out:
# rad
# 1     291.450000
# 2     260.666667
# 3     246.078947
# 4     335.981818
# 5     331.843478
# 6     372.884615
# 7     304.411765
# 8     301.250000
# 24    666.000000
# Name: tax, dtype: float64

# %%
display( boston.groupby("rad")["tax"].mean().to_frame() )
# Out:
#             tax
# rad
# 1    291.450000
# 2    260.666667
# 3    246.078947
# 4    335.981818
# 5    331.843478
# 6    372.884615
# 7    304.411765
# 8    301.250000
# 24   666.000000
